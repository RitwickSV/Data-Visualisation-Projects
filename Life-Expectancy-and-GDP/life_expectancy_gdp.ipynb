# %% [markdown]
# # Project Goals
#
# This project deals with the life expectancy and the GDP of people. We analyse the data that we have received and shall draw conclusions and try to answer questions by tidying, wrangling and manipulating the data.
#
# Let's start by importing all the modules we would require for running the project.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load the data into a dataframe and try to observe the data
raw_data = pd.read_csv('all_data.csv')

# %%
raw_data
# Out:
#      Country  Year  Life expectancy at birth (years)           GDP
# 0      Chile  2000                              77.3  7.786093e+10
# 1      Chile  2001                              77.3  7.097992e+10
# 2      Chile  2002                              77.8  6.973681e+10
# 3      Chile  2003                              77.9  7.564346e+10
# 4      Chile  2004                              78.0  9.921039e+10
# ..       ...   ...                               ...           ...
# 91  Zimbabwe  2011                              54.9  1.209845e+10
# 92  Zimbabwe  2012                              56.6  1.424249e+10
# 93  Zimbabwe  2013                              58.0  1.545177e+10
# 94  Zimbabwe  2014                              59.2  1.589105e+10
# 95  Zimbabwe  2015                              60.7  1.630467e+10
#
# [96 rows x 4 columns]

# %%
def fx_country_life(country, data):
    data_sliced = data[data.Country == country]
    plt.plot(data_sliced.Year, data_sliced['Life expectancy at birth (years)'], label = country)
    
def fx_country_gdp(country, data):
    data_sliced = data[data.Country == country]
    plt.plot(data_sliced.Year, data_sliced.GDP, label = country)

# %%
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
for country in list(df.Country.unique()):
    fx_country_life(country, df)
plt.xlabel('Years')
plt.ylabel('Life Expectancy (years)')
plt.title('Life Expectancy Along the years')
plt.legend()

plt.subplot(1,2,2)
for country in list(df.Country.unique()):
    fx_country_gdp(country, df)
plt.xlabel('Years')
plt.ylabel('GDP')
plt.title('GDP Along the years')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(16,8))
plt.subplot(1,2,1)
sns.boxplot(x = df.Country, y = df['Life expectancy at birth (years)'])
plt.xticks(rotation = 85)

plt.subplot(1,2,2)
sns.boxplot(x = df.Country, y = df['GDP'])
plt.xticks(rotation = 85)

plt.show()
